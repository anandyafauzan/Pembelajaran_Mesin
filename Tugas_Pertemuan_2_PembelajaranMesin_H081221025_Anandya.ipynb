# %% [markdown]
# <a href="https://colab.research.google.com/github/anandyafauzan/Pembelajaran_Mesin/blob/main/Tugas_Pertemuan_2_PembelajaranMesin_H081221025_Anandya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cara Manual

# %%
import pandas as pd

# %%
dataset = '/content/Billionaires Statistics Dataset.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
data.head()
# Out:
#    rank  finalWorth               category                personName   age  \
# 0     1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1     2      180000             Automotive                 Elon Musk  51.0
# 2     3      114000             Technology                Jeff Bezos  59.0
# 3     4      107000             Technology             Larry Ellison  78.0
# 4     5      106000  Finance & Investments            Warren Buffett  92.0
#
#          country    city              source             industries  \
# 0         France   Paris                LVMH       Fashion & Retail
# 1  United States  Austin       Tesla, SpaceX             Automotive
# 2  United States  Medina              Amazon             Technology
# 3  United States   Lanai              Oracle             Technology
# 4  United States   Omaha  Berkshire Hathaway  Finance & Investments
#
#   countryOfCitizenship  ... cpi_change_country           gdp_country  \
# ...

# %%
print(data.dtypes)
# Out:
# rank                                            int64
# finalWorth                                      int64
# category                                       object
# personName                                     object
# age                                           float64
# country                                        object
# city                                           object
# source                                         object
# industries                                     object
# countryOfCitizenship                           object
# organization                                   object
# selfMade                                         bool
# status                                         object
# gender                                         object
# birthDate                                      object
# lastName                                       object
# firstName                                      object
# ...

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#       rank  finalWorth               category                personName  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family
# 1        2      180000             Automotive                 Elon Musk
# 2        3      114000             Technology                Jeff Bezos
# 3        4      107000             Technology             Larry Ellison
# 4        5      106000  Finance & Investments            Warren Buffett
# ...    ...         ...                    ...                       ...
# 2635  2540        1000             Healthcare                   Yu Rong
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.
# 2637  2540        1000          Manufacturing             Zhang Gongyun
# 2638  2540        1000            Real Estate    Zhang Guiping & family
# 2639  2540        1000            Diversified               Inigo Zobel
#
#             country        city                        source  \
# ...

# %%
data.describe()
# Out:
#               rank     finalWorth          age    birthYear   birthMonth  \
# count  2640.000000    2640.000000  2575.000000  2564.000000  2564.000000
# mean   1289.159091    4623.787879    65.140194  1957.183307     5.740250
# std     739.693726    9834.240939    13.258098    13.282516     3.710085
# min       1.000000    1000.000000    18.000000  1921.000000     1.000000
# 25%     659.000000    1500.000000    56.000000  1948.000000     2.000000
# 50%    1312.000000    2300.000000    65.000000  1957.000000     6.000000
# 75%    1905.000000    4200.000000    75.000000  1966.000000     9.000000
# max    2540.000000  211000.000000   101.000000  2004.000000    12.000000
#
#           birthDay  cpi_country  cpi_change_country  \
# count  2564.000000  2456.000000         2456.000000
# mean     12.099844   127.755204            4.364169
# std       9.918876    26.452951            3.623763
# min       1.000000    99.550000           -1.900000
# ...

# %%
data.loc[:,"age":].corr()
# Out:
# <ipython-input-16-1b8b474215e8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"age":].corr()
#                                                  age  selfMade  birthYear  \
# age                                         1.000000 -0.050538  -0.999336
# selfMade                                   -0.050538  1.000000   0.050333
# birthYear                                  -0.999336  0.050333   1.000000
# birthMonth                                  0.015322  0.001391  -0.045066
# birthDay                                    0.081547 -0.030345  -0.091512
# cpi_country                                -0.001479 -0.015086  -0.000738
# cpi_change_country                          0.115669  0.031552  -0.118060
# gross_tertiary_education_enrollment         0.061736  0.012241  -0.061316
# ...

# %%
# @title rank vs final worth

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='rank', y='finalWorth', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dengan API

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-8bbd4bda-d5a0-482e-b80d-5cc2796e3093" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bbd4bda-d5a0-482e-b80d-5cc2796e3093">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Billionaires Statistics Dataset (2023)"
# Out:
# ...
# ref                                               title                                    size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------  --------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/billionaires-statistics-dataset  Billionaires Statistics Dataset (2023)  139KB  2023-09-29 13:39:28          20544        432  1.0

# %%
# !kaggle datasets download nelgiriyewithana/billionaires-statistics-dataset
# Out:
# ...
#   0% 0.00/139k [00:00<?, ?B/s]
# 100% 139k/139k [00:00<00:00, 65.3MB/s]

# %%
# !unzip /content/billionaires-statistics-dataset.zip
# Out:
# Archive:  /content/billionaires-statistics-dataset.zip
#   inflating: Billionaires Statistics Dataset.csv

# %%
pd.read_csv('/content/Billionaires Statistics Dataset.csv')
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...
